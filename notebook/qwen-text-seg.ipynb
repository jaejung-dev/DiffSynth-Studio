# %% [markdown]
# # Qwen Text Seg inference (single image)
#
# This notebook runs the **full** text-seg checkpoint with a single input image.
#
# Steps:
# 1) Download weights into the repo root.
# 2) Set `INPUT_IMAGE_PATH` below.
# 3) Run all cells.
#
# Notes:
# - Uses `edit_image` only (same convention as `validate_lora/Qwen-Image-Edit-2511-LayeredVAE_FG_seg.py`).
# - Outputs are saved to `output/qwen_text_seg_infer/`.

# %%
import os
from pathlib import Path

import torch
from PIL import Image
from IPython.display import display

from diffsynth.pipelines.qwen_image import QwenImagePipeline, ModelConfig
from diffsynth import load_state_dict


def _find_repo_root(start: Path) -> Path:
    for parent in [start] + list(start.parents):
        if (parent / "diffsynth").exists() and (parent / "pyproject.toml").exists():
            return parent
    return start


def _resolve_model_base(repo_root: Path) -> Path:
    env = os.environ.get("DIFFSYNTH_MODEL_BASE_PATH","/mnt/lica-data-2/for_jjseol/diffsynth_models")#"/mnt/local/diffsynth_models")
    if env:
        return Path(env)
    candidates = [
        repo_root / "diffsynth_models",
        Path("/mnt/lica-data-2/for_jjseol/diffsynth_models"),
        Path("/mnt/data/for_jjseol/diffsynth_models"),
    ]
    for cand in candidates:
        if (cand / "Qwen").exists():
            return cand
    return candidates[0]


REPO_ROOT = _find_repo_root(Path(".").resolve())
DEFAULT_MODEL_BASE = _resolve_model_base(REPO_ROOT)
print(f"[model] base: {DEFAULT_MODEL_BASE}")

PROMPT = "Extract the text layer."
SEED = 123
STEPS = 40

FULL_CKPT_DIR = Path("/mnt/lica-data-2/for_jjseol/diffsynth_models/train/Qwen-Image-Edit-2511_full_layered_vae_text_fg_seg")
FULL_CKPT = FULL_CKPT_DIR / "step-5000k.safetensors"

OUTPUT_DIR = REPO_ROOT / "output/qwen_text_seg_infer"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# [model] base: /mnt/lica-data-2/for_jjseol/diffsynth_models

# %%
import glob


def _model_config_local_only(local_glob: str, label: str) -> ModelConfig:
    paths = sorted(glob.glob(local_glob))
    if not paths:
        raise FileNotFoundError(f"[model] Missing local weights for {label}: {local_glob}")
    path_value = paths if len(paths) > 1 else paths[0]
    print(f"[model] Using local weights: {path_value}")
    return ModelConfig(path=path_value)


def _aux_config_local_only(local_dir: Path, label: str) -> ModelConfig:
    if not local_dir.exists():
        raise FileNotFoundError(f"[aux] Missing local assets for {label}: {local_dir}")
    print(f"[aux] Using local assets: {local_dir}")
    return ModelConfig(path=str(local_dir))


def _resolve_ckpt_path(path: Path) -> Path:
    if path.is_dir():
        candidates = sorted(path.glob("*.safetensors"), key=lambda p: p.stat().st_mtime)
        if not candidates:
            raise FileNotFoundError(f"No checkpoints found in: {path}")
        return candidates[-1]
    return path


device = "cuda" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.bfloat16 if device == "cuda" else torch.float32

model_base = DEFAULT_MODEL_BASE
qwen_root = model_base / "Qwen"

pipe = QwenImagePipeline.from_pretrained(
    torch_dtype=torch_dtype,
    device=device,
    model_configs=[
        _model_config_local_only(
            str(qwen_root / "Qwen-Image-Edit-2511" / "transformer" / "diffusion_pytorch_model-*.safetensors"),
            "Qwen-Image-Edit-2511 transformer",
        ),
        _model_config_local_only(
            str(qwen_root / "Qwen-Image" / "text_encoder" / "model*.safetensors"),
            "Qwen-Image text encoder",
        ),
        _model_config_local_only(
            str(qwen_root / "Qwen-Image-Layered" / "vae" / "diffusion_pytorch_model.safetensors"),
            "Qwen-Image-Layered VAE",
        ),
    ],
    tokenizer_config=None,
    processor_config=_aux_config_local_only(qwen_root / "Qwen-Image-Edit" / "processor", "Qwen-Image-Edit processor"),
)

ckpt_path = _resolve_ckpt_path(FULL_CKPT if FULL_CKPT.exists() else FULL_CKPT_DIR)
print(f"[ckpt] Using full checkpoint: {ckpt_path}")
state_dict = load_state_dict(str(ckpt_path))
pipe.dit.load_state_dict(state_dict)
# Out:
# [model] Using local weights: ['/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00001-of-00005.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00002-of-00005.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00003-of-00005.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00004-of-00005.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00005-of-00005.safetensors']
# [model] Using local weights: ['/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image/text_encoder/model-00001-of-00004.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image/text_encoder/model-00002-of-00004.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image/text_encoder/model-00003-of-00004.safetensors', '/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image/text_encoder/model-00004-of-00004.safetensors']
# [model] Using local weights: /mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Layered/vae/diffusion_pytorch_model.safetensors
# [aux] Using local assets: /mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit/processor
# Loading models from: [
#     "/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00001-of-00005.safetensors",
#     "/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00002-of-00005.safetensors",
#     "/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00003-of-00005.safetensors",
#     "/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00004-of-00005.safetensors",
#     "/mnt/lica-data-2/for_jjseol/diffsynth_models/Qwen/Qwen-Image-Edit-2511/transformer/diffusion_pytorch_model-00005-of-00005.safetensors"
# ]
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[3], line 35
#      32 model_base = DEFAULT_MODEL_BASE
#      33 qwen_root = model_base / "Qwen"
# ---> 35 pipe = QwenImagePipeline.from_pretrained(
#      36     torch_dtype=torch_dtype,
#      37     device=device,
#      38     model_configs=[
#      39         _model_config_local_only(
#      40             str(qwen_root / "Qwen-Image-Edit-2511" / "transformer" / "diffusion_pytorch_model-*.safetensors"),
#      41             "Qwen-Image-Edit-2511 transformer",
#      42         ),
#      43         _model_config_local_only(
#      44             str(qwen_root / "Qwen-Image" / "text_encoder" / "model*.safetensors"),
#      45             "Qwen-Image text encoder",
#      46         ),
#      47         _model_config_local_only(
#      48             str(qwen_root / "Qwen-Image-Layered" / "vae" / "diffusion_pytorch_model.safetensors"),
#      49             "Qwen-Image-Layered VAE",
#      50         ),
#      51     ],
#      52     tokenizer_config=None,
#      53     processor_config=_aux_config_local_only(qwen_root / "Qwen-Image-Edit" / "processor", "Qwen-Image-Edit processor"),
#      54 )
#      56 ckpt_path = _resolve_ckpt_path(FULL_CKPT if FULL_CKPT.exists() else FULL_CKPT_DIR)
#      57 print(f"[ckpt] Using full checkpoint: {ckpt_path}")
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/pipelines/qwen_image.py:71, in QwenImagePipeline.from_pretrained(torch_dtype, device, model_configs, tokenizer_config, processor_config, vram_limit)
#      60 @staticmethod
#      61 def from_pretrained(
#      62     torch_dtype: torch.dtype = torch.bfloat16,
#    (...)     68 ):
#      69     # Initialize pipeline
#      70     pipe = QwenImagePipeline(device=device, torch_dtype=torch_dtype)
# ---> 71     model_pool = pipe.download_and_load_models(model_configs, vram_limit)
#      73     # Fetch models
#      74     pipe.text_encoder = model_pool.fetch_model("qwen_image_text_encoder")
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/diffusion/base_pipeline.py:293, in BasePipeline.download_and_load_models(self, model_configs, vram_limit)
#     291     vram_config["computation_dtype"] = vram_config["computation_dtype"] or self.torch_dtype
#     292     vram_config["computation_device"] = vram_config["computation_device"] or self.device
# --> 293     model_pool.auto_load_model(
#     294         model_config.path,
#     295         vram_config=vram_config,
#     296         vram_limit=vram_limit,
#     297         clear_parameters=model_config.clear_parameters,
#     298     )
#     299 return model_pool
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/models/model_loader.py:70, in ModelPool.auto_load_model(self, path, vram_config, vram_limit, clear_parameters)
#      68 for config in MODEL_CONFIGS:
#      69     if config["model_hash"] == model_hash:
# ---> 70         model = self.load_model_file(config, path, vram_config, vram_limit=vram_limit)
#      71         if clear_parameters: self.clear_parameters(model)
#      72         self.model.append(model)
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/models/model_loader.py:40, in ModelPool.load_model_file(self, config, path, vram_config, vram_limit)
#      38     state_dict_converter = None
#      39 module_map = self.fetch_module_map(config["model_class"], vram_config)
# ---> 40 model = load_model(
#      41     model_class, path, model_config,
#      42     vram_config["computation_dtype"], vram_config["computation_device"],
#      43     state_dict_converter,
#      44     use_disk_map=True,
#      45     vram_config=vram_config, module_map=module_map, vram_limit=vram_limit,
#      46 )
#      47 return model
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/core/loader/model.py:48, in load_model(model_class, path, config, torch_dtype, device, state_dict_converter, use_disk_map, module_map, vram_config, vram_limit)
#      46     state_dict = state_dict_converter(state_dict)
#      47 else:
# ---> 48     state_dict = {i: state_dict[i] for i in state_dict}
#      49 model.load_state_dict(state_dict, assign=True)
#      50 # Why do we call `to()`?
#      51 # Because some models override the behavior of `to()`,
#      52 # especially those from libraries like Transformers.
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/core/loader/model.py:48, in <dictcomp>(.0)
#      46     state_dict = state_dict_converter(state_dict)
#      47 else:
# ---> 48     state_dict = {i: state_dict[i] for i in state_dict}
#      49 model.load_state_dict(state_dict, assign=True)
#      50 # Why do we call `to()`?
#      51 # Because some models override the behavior of `to()`,
#      52 # especially those from libraries like Transformers.
#
# File ~/miniconda3/envs/jaepoong/lib/python3.11/site-packages/diffsynth/core/vram/disk_map.py:62, in DiskMap.__getitem__(self, name)
#      60 if self.rename_dict is not None: name = self.rename_dict[name]
#      61 file_id = self.name_map[name]
# ---> 62 param = self.files[file_id].get_tensor(name)
#      63 if self.torch_dtype is not None and isinstance(param, torch.Tensor):
#      64     param = param.to(self.torch_dtype)
#
# AcceleratorError: CUDA error: out of memory
# Search for `cudaErrorMemoryAllocation' in https://docs.nvidia.com/cuda/cuda-runtime-api/group__CUDART__TYPES.html for more information.
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
def _checkerboard_rgba(size, tile=32):
    w, h = size
    light = (200, 200, 200, 255)
    dark = (160, 160, 160, 255)
    bg = Image.new("RGBA", size, light)
    tile_img = Image.new("RGBA", (tile, tile), dark)
    for y in range(0, h, tile):
        for x in range(0, w, tile):
            if (x // tile + y // tile) % 2 == 1:
                bg.paste(tile_img, (x, y))
    return bg

MAX_SIDE = 1024
ROUND_TO = 32
# When True, pipeline auto-resizes edit_image to ~1024x1024 area.
EDIT_IMAGE_AUTO_RESIZE = False
SHOW_INPUT_COPY = True


def _resize_edit_image(image, max_side=1024, round_to=32):
    w, h = image.size
    scale = min(1.0, max_side / max(w, h))
    new_w = int(round(w * scale))
    new_h = int(round(h * scale))
    if round_to:
        new_w = max(round_to, (new_w // round_to) * round_to)
        new_h = max(round_to, (new_h // round_to) * round_to)
    if (new_w, new_h) != (w, h):
        image = image.resize((new_w, new_h), Image.LANCZOS)
    return image

INPUT_IMAGE_PATH = Path("/home/ubuntu/854f04d5-082a-450a-93aa-cf0d4ea362c0_generated_image.png")
if not INPUT_IMAGE_PATH.exists():
    raise FileNotFoundError(f"Input image not found: {INPUT_IMAGE_PATH}")

edit_image = Image.open(INPUT_IMAGE_PATH).convert("RGBA")
orig_size = edit_image.size
edit_image = _resize_edit_image(edit_image, max_side=MAX_SIDE, round_to=ROUND_TO)
if edit_image.size != orig_size:
    print(f"[input] resized {orig_size[0]}x{orig_size[1]} -> {edit_image.size[0]}x{edit_image.size[1]}")
width, height = edit_image.size
SEED += 1
STEPS = 10
PROMPT = "Extract the text layer."
result = pipe(
    PROMPT,
    edit_image=edit_image,
    seed=SEED,
    num_inference_steps=STEPS,
    height=height,
    width=width,
    edit_image_auto_resize=EDIT_IMAGE_AUTO_RESIZE,
    zero_cond_t=True,
)

# Match output size for display
output_rgba = result.convert("RGBA")
output_size = output_rgba.size
if edit_image.size != output_size:
    edit_image = edit_image.resize(output_size, Image.LANCZOS)

# Build preview: edit | output | (optional input copy)
checker_bg = _checkerboard_rgba(output_size)
output_composite = Image.alpha_composite(checker_bg, output_rgba)

out_w, out_h = output_size
canvas = Image.new("RGBA", (out_w * 2, out_h), (0, 0, 0, 0))
canvas.paste(edit_image, (0, 0))
canvas.paste(output_composite, (out_w, 0))
suffix = "pair"

out_path = OUTPUT_DIR / f"{INPUT_IMAGE_PATH.stem}_{suffix}.png"
canvas.save(out_path)

print(f"[done] saved to {out_path}")
display(canvas)

# Alpha mask where output alpha > 50
alpha = output_rgba.getchannel("A")
mask = alpha.point(lambda v: 255 if v > 20 else 0)
mask_path = OUTPUT_DIR / f"{INPUT_IMAGE_PATH.stem}_mask.png"
mask.save(mask_path)
print(f"[done] saved mask to {mask_path}")
display(mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 32
#      29         image = image.resize((new_w, new_h), Image.LANCZOS)
#      30     return image
# ---> 32 INPUT_IMAGE_PATH = Path("/home/ubuntu/854f04d5-082a-450a-93aa-cf0d4ea362c0_generated_image.png")
#      33 if not INPUT_IMAGE_PATH.exists():
#      34     raise FileNotFoundError(f"Input image not found: {INPUT_IMAGE_PATH}")
#
# NameError: name 'Path' is not defined

# %%
alpha = output_rgba.getchannel("A")
mask = alpha.point(lambda v: 255 if v > 10 else 0)
mask_path = OUTPUT_DIR / f"{INPUT_IMAGE_PATH.stem}_mask.png"
mask.save(mask_path)
print(f"[done] saved mask to {mask_path}")
display(mask)
# Out:
# [done] saved mask to /home/ubuntu/DiffSynth-Studio/output/qwen_text_seg_infer/854f04d5-082a-450a-93aa-cf0d4ea362c0_generated_image_mask.png
# <PIL.Image.Image image mode=L size=544x1024>
